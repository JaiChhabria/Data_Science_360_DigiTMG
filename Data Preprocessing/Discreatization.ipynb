# %% [markdown]
# # Discreatization

# %% [markdown]
# Loading necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading our dataset `iris dataset`

# %%
df = pd.read_csv('iris.csv')
df # We can see we have addition column without header which is Unnamed:0
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df.columns # We can see we have addition column without header which is Unnamed:0, we will remove this column from our dataframe
# Out:
# Index(['Unnamed: 0', 'Sepal.Length', 'Sepal.Width', 'Petal.Length',
#        'Petal.Width', 'Species'],
#       dtype='object')

# %%
columns_to_drop = ['Unnamed: 0']
df = df.drop(columns=columns_to_drop)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Lets check the shape and lets describe our data

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # As we can see apart from `Species` column all other columns are continous columns, we will use following methods to discreatization our columns

# %% [markdown]
# We will discreate following columns `Sepal.Length`, `Sepal.Width`, `Petal.Length`, `Petal.Width`
#
# We will use following techniques:
# 1 - Binarization
# 2 - Rounding
# 3 - Binning

# %% [markdown]
# ## Step 1 - Binarization

# %%
# We will use Python qcut, to categorize our value to be either Below Median or Above Median

# We will use this logic for each column and create seperate columns which will show Binarization in our dataset

# %%
bins_label = ['Below_Median', 'Above_Median'] # Creating Labels for our Binarization

# %% [markdown]
# Transforming our columns in Dataset

# %%
df['Sepal_Length_Binarization'] = pd.qcut(df['Sepal.Length'], q=2,
                                         labels=bins_label) # We are cutting our data into 50% qunatile and we are categorzing our Sepal length to be either above Median or Below median
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Sepal_Length_Binarization
# 0                Below_Median
# 1                Below_Median
# 2                Below_Median
# ...

# %%
df['Sepal_Width_Binarization'] = pd.qcut(df['Sepal.Width'], q=2,
                                        labels=bins_label)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Sepal_Length_Binarization Sepal_Width_Binarization
# 0                Below_Median             Above_Median
# ...

# %%
df['Petal_Length_Binarization'] = pd.qcut(df['Petal.Length'], q=2,
                                         labels=bins_label)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Sepal_Length_Binarization Sepal_Width_Binarization  \
# 0                Below_Median             Above_Median
# ...

# %%
df['Petal_Width_Binarization'] =pd.qcut(df['Petal.Width'], q=2,
                                       labels=bins_label)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Sepal_Length_Binarization Sepal_Width_Binarization  \
# 0                Below_Median             Above_Median
# ...

# %% [markdown]
# We have sucessfully Binarized our continous data to be in two categories which is Above Median or Below Median

# %% [markdown]
# # Step 2 - Rounding

# %%
## We will round the numbers to their nearest Integer

# %%
## We will load the data again

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
columns_to_drop = ['Unnamed: 0']
df = df.drop(columns=columns_to_drop)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['Sepal_Length_Rounded'] = np.array(np.round((df['Sepal.Length'])), dtype='int') # Rounding Sepal.Length column to its nearest integer and saving that information to a new column
df
# We will replicate the same process for other columns in the dataframe
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_Length_Rounded
# 0                       5
# 1                       5
# 2                       5
# 3                       5
# ...

# %%
df['Sepal_width_Rounded'] = np.array(np.round((df['Sepal.Width'])), dtype='int')
df['Petal_Length_Rounded'] = np.array(np.round((df['Petal.Length'])),dtype='int')
df['Petal_Width_Rounded'] = np.array(np.round((df['Petal.Width'])), dtype='int')
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_Length_Rounded  Sepal_width_Rounded  Petal_Length_Rounded  \
# ...

# %% [markdown]
# We have sucessfully Rounded our continous data to its nearest `Integer`

# %% [markdown]
# # Step 3 - Binning

# %% [markdown]
# We will use the `cut` method in `Pandas` to bin our variables

# %%
# We will try to Bin our data with Adaptive bins of 3

# %%
pd.cut(df['Petal.Length'],3).head() # This shows all the values of Petal Length being Binned under 3 bins values are available below Categories
# Out:
# 0    (0.0976, 0.9]
# 1    (0.0976, 0.9]
# 2    (0.0976, 0.9]
# 3    (0.0976, 0.9]
# 4    (0.0976, 0.9]
# Name: Petal.Width, dtype: category
# Categories (3, interval[float64]): [(0.0976, 0.9] < (0.9, 1.7] < (1.7, 2.5]]

# %% [markdown]
# Lets assign these values to our data frame

# %%
## Lets load the data again
df = pd.read_csv('iris.csv')
df
columns_to_drop = ['Unnamed: 0']
df = df.drop(columns=columns_to_drop)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['Sepal.Length_Bin'] = pd.cut(df['Sepal.Length'],3)
df['Speal.Width_Bin'] = pd.cut(df['Sepal.Width'],3)
df['Petal.Lenght_Bin'] = pd.cut(df['Petal.Length'],3)
df['Petal.Width_Bin'] = pd.cut(df['Petal.Width'],3)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Sepal.Length_Bin Speal.Width_Bin Petal.Lenght_Bin Petal.Width_Bin
# ...

# %%
# We can see bin size does not match as they adapt to the values of each column

# %%
# We will use Fixed width bins

# %%
# Lets load the data again
df = pd.read_csv('iris.csv')
df
columns_to_drop = ['Unnamed: 0']
df = df.drop(columns=columns_to_drop)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# from the data set, we can see max value is 7.9 and min value is 0.100000

# We will create an array of 5 values which will be between 0.1 to 8

custom_bin = np.linspace(0.1, 8, 5)
custom_bin
# Out:
# array([0.1  , 2.075, 4.05 , 6.025, 8.   ])

# %%
# We will provide our custom bin value to our cut to bin values only between these values

# %%
df['Sepal.Length_Bin'] = pd.cut(df['Sepal.Length'],custom_bin)
df['Speal.Width_Bin'] = pd.cut(df['Sepal.Width'],custom_bin)
df['Petal.Lenght_Bin'] = pd.cut(df['Petal.Length'],custom_bin)
df['Petal.Width_Bin'] = pd.cut(df['Petal.Width'],custom_bin)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Sepal.Length_Bin Speal.Width_Bin Petal.Lenght_Bin Petal.Width_Bin
# ...
