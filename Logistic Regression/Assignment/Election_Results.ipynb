# %% [markdown]
# # Problem Statement

# %% [markdown]
# Perform Logistic Regression on the dataset to predict whether a candidate will win or lose the election based on factors like amount of money spent and popularity rank.

# %% [markdown]
# ---- #### -----

# %% [markdown]
# Lets load our libraries and dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,15)

# %%
data = pd.read_csv('election_data.csv')
data
# Out:
#    Election-id  Result  Year  Amount Spent  Popularity Rank
# 0          122       0    32          3.81                3
# 1          315       1    48          6.32                2
# 2          201       1    51          3.67                1
# 3          965       0    40          2.93                4
# 4          410       1    52          3.60                1
# 5          150       0    35          4.20                4
# 6          743       1    39          5.66                2
# 7          612       1    42          4.32                3
# 8          206       1    44          3.26                3
# 9          792       0    50          4.52                4

# %%
data.shape
# Out:
# (10, 5)

# %% [markdown]
# Lets explore and visualize our dataset

# %%
data.dtypes
# Out:
# Election-id          int64
# Result               int64
# Year                 int64
# Amount Spent       float64
# Popularity Rank      int64
# dtype: object

# %%
msno.bar(data)

# %% [markdown]
# There are no missing values in our dataset

# %%
data.describe()
# Out:
#        Election-id     Result       Year  Amount Spent  Popularity Rank
# count    10.000000  10.000000  10.000000     10.000000        10.000000
# mean    451.600000   0.600000  43.300000      4.229000         2.700000
# std     304.266404   0.516398   6.912951      1.055351         1.159502
# min     122.000000   0.000000  32.000000      2.930000         1.000000
# 25%     202.250000   0.000000  39.250000      3.617500         2.000000
# 50%     362.500000   1.000000  43.000000      4.005000         3.000000
# 75%     710.250000   1.000000  49.500000      4.470000         3.750000
# max     965.000000   1.000000  52.000000      6.320000         4.000000

# %%
data.columns
# Out:
# Index(['Election-id', 'Result', 'Year', 'Amount Spent', 'Popularity Rank'], dtype='object')

# %%
data[['Election-id', 'Year', 'Amount Spent', 'Popularity Rank']].plot(kind='box')

# %%
sns.heatmap(data[['Election-id', 'Result', 'Year', 'Amount Spent', 'Popularity Rank']].corr(),annot=True,cmap='RdYlGn')

# %%
sns.scatterplot('Amount Spent','Popularity Rank',hue='Result',data=data)

# %% [markdown]
# From the above chart we can see anyone with Popularity Rank of 4 has never won the election

# %% [markdown]
# We cannot build any model as we can clearly see if anyone has a rank of 4, then the result will be 0 and if anyone rank is either 1 or 2, their result is 1
